# %%
import pandas as pd
import numpy as np
import seaborn as sns
df=pd.read_excel(r'C:\Users\saranga\Desktop\SQL\My Data\mart_train_sample.xlsx')

# %%
df.head()
# Out:
#   Item_ID     Item_W              Item_Type    Item_MRP Outlet_ID  \
# 0   FDN27   9.437510            Snack Foods  195.313244    OUT046
# 1   FDW35   9.033762  Fruits and Vegetables   36.371449    OUT035
# 2   FDS28  20.884849           Frozen Foods   70.318167    OUT013
# 3   FDC09  19.976300            Snack Foods  121.723264    OUT018
# 4   FDX04  10.824812            Snack Foods  264.673302    OUT035
#
#    Outlet_Year Outlet_Size Outlet_Location_Type        Sales  Tier
# 0         1997       Small               Tier 1   897.085562     1
# 1         2003       Small               Tier 2  1639.303513     2
# 2         2008       Small               Tier 1  2664.773737     1
# 3         2009      Medium               Tier 3   440.859593     3
# 4         2004       Small               Tier 1    29.807098     1

# %%
df.columns
# Out:
# Index(['Item_ID', 'Item_W', 'Item_Type', 'Item_MRP', 'Outlet_ID',
#        'Outlet_Year', 'Outlet_Size', 'Outlet_Location_Type', 'Sales', 'Tier'],
#       dtype='object')

# %%
sns.scatterplot(data=df, x="Item_MRP", y="Sales")
# Out:
# <Axes: xlabel='Item_MRP', ylabel='Sales'>

# %% [markdown]
# #### Grouping Basis on a Categorical Variable Using Hue

# %%
sns.scatterplot(data=df, x="Item_MRP", y="Sales", hue="Outlet_Size", )  
plt.show()

# %% [markdown]
# ### Grouping basis on a categorical Variable Using STYLE and stylig Markers AS Well

# %%
sns.scatterplot(data=df, x="Item_MRP", y="Sales",style="Outlet_Size")
# Out:
# <Axes: xlabel='Item_MRP', ylabel='Sales'>

# %% [markdown]
# #### Add Dictionary

# %%
sns.scatterplot(data=df, x="Item_MRP", y="Sales", style="Outlet_Size",
                markers={"High": "^", "Small": "v", "Medium": "o"})
# Out:
# <Axes: xlabel='Item_MRP', ylabel='Sales'>

# %% [markdown]
# ### hue

# %%
sns.scatterplot(data=df, x="Item_MRP", y="Sales", style="Outlet_Size", hue="Outlet_Size",
                markers={"High": "^", "Small": "v", "Medium": "o"})
# Out:
# <Axes: xlabel='Item_MRP', ylabel='Sales'>

# %% [markdown]
# ### Palette

# %%
sns.scatterplot(data=df, x="Item_MRP", y="Sales", style="Outlet_Size", hue="Outlet_Size",
                palette="crest_r",
                markers={"High": "^", "Small": "v", "Medium": "o"})
# Out:
# <Axes: xlabel='Item_MRP', ylabel='Sales'>

# %%
sns.scatterplot(data=df, x="Item_MRP", y="Sales", style="Outlet_Size", 
                hue="Outlet_Size",
                palette="crest_r",
                size="Outlet_Size",
                markers={"High": "^", "Small": "v", "Medium": "o"})
# Out:
# <Axes: xlabel='Item_MRP', ylabel='Sales'>

# %%
sns.scatterplot(data=df, x="Item_MRP", y="Sales", color="blue", s=300)
# Out:
# <Axes: xlabel='Item_MRP', ylabel='Sales'>

# %%
df.columns
# Out:
# Index(['Item_ID', 'Item_W', 'Item_Type', 'Item_MRP', 'Outlet_ID',
#        'Outlet_Year', 'Outlet_Size', 'Outlet_Location_Type', 'Sales', 'Tier'],
#       dtype='object')

# %% [markdown]
# # Line Plot

# %% [markdown]
# ### Creat abasic line plot and try different estimators

# %%
sns.lineplot(data=df, x="Outlet_Year", y="Sales", ci=None, estimator=sum)
# Out:
# C:\Users\saranga\AppData\Local\Temp\ipykernel_14612\1297745170.py:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.lineplot(data=df, x="Outlet_Year", y="Sales", ci=None, estimator=sum)
# <Axes: xlabel='Outlet_Year', ylabel='Sales'>

# %%
sns.lineplot(data=df, x="Outlet_Year", y="Sales", errorbar=None,  )
# Out:
# <Axes: xlabel='Outlet_Year', ylabel='Sales'>

# %% [markdown]
# ## Test with different Confidence Intervals and with different number of Bootstraping

# %%
sns.lineplot(data=df, x="Outlet_Year", y="Sales", errorbar='sd')
# Out:
# <Axes: xlabel='Outlet_Year', ylabel='Sales'>

# %% [markdown]
# #### Bootstraping

# %%
sns.lineplot(data=df, x="Outlet_Year", y="Sales", n_boot=20)
# Out:
# <Axes: xlabel='Outlet_Year', ylabel='Sales'>

# %%
sns.lineplot(data=df, x="Outlet_Year", y="Sales", errorbar=None, hue="Outlet_Size")
# Out:
# <Axes: xlabel='Outlet_Year', ylabel='Sales'>

# %% [markdown]
# ### Grouping Using Style Use different Marker AND Dashes

# %%
sns.lineplot(data=df, x="Outlet_Year", y="Sales", errorbar=None,
            style="Outlet_Size",
            markers=True,
            dashes=False)
# Out:
# <Axes: xlabel='Outlet_Year', ylabel='Sales'>

# %% [markdown]
# ## Grouping Using Size

# %%
sns.lineplot(data=df,x="Outlet_Year", y="Sales", errorbar=None, size="Outlet_Size")
# Out:
# <Axes: xlabel='Outlet_Year', ylabel='Sales'>

# %%
sns.lineplot(data=df,x="Outlet_Year",y="Sales", errorbar=None, 
hue="Outlet_Size",
style="Outlet_Size",
markers=True)
# Out:
# <Axes: xlabel='Outlet_Year', ylabel='Sales'>

# %%
sns.lineplot(data=df,x="Outlet_Year",y="Sales", errorbar=None, 
hue="Outlet_Size",
style="Tier",
markers=True)
# Out:
# <Axes: xlabel='Outlet_Year', ylabel='Sales'>

# %% [markdown]
# ## Relplot

# %% [markdown]
# ### Creat abasic Relplot plot and try different estimators

# %%
sns.relplot(data=df,x="Outlet_Year",y="Sales",
            s=100,
            hue="Outlet_Size",
            col="Item_Type",
           col_wrap=5)

# %%
sns.relplot(data=df,x="Outlet_Year",y="Sales",
            s=100,
            hue="Outlet_Size",
            palette=["green", "red" , "yellow"])
